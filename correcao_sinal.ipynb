# %% [markdown]
# ### Automação correção de sinal.
#
# O teste inicial será realizado com uma planilha montada manualmente, apenas para testes.
# Abaixo está a leitura principal da planilha, de filtrando as linhas sem o nome do cliente

# %%
#Passo 1: ler e mostrar o documento .csv
import pandas as pd
# 1.1 importar a tabela do google sheets
url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vR7cDOUhlIA69krlJzPfzyBPVjrefjR9RWDQknYhoj7sW7cN3xQVgvYdpWhdLHDbQ-6MlvwuEx4Lg2_/pub?output=csv"
# 1.2 ler a tabela e mostrar as informações
mnova = pd.read_csv(url)
mnova = mnova.dropna()
#display(mnova.info())
display(mnova)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 82 entries, 0 to 129
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Nome_Cliente  82 non-null     object
#  1   PPPoE         82 non-null     object
#  2   Sinal         82 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 2.6+ KB
# None
#                                   Nome_Cliente  \
# 0                        Antonio Juliano Silva
# 1                Sao Mateus Agropecuaria LTDA.
# 4                       Suemar Lazaro de Souza
# 6               Alexia Terra do Vale Magalhaes
# 8    Sucuriu Empreendimentos Imobiliarios Ltda
# ..                                         ...
# 122             Dulce Aparecida Soares Valerio
# 124                  Fabio Machado de Carvalho
# 125                   Rodrigo Barbosa Da Silva
# 127                   Maria de Lourdes e Silva
# 129                  Antonio Cassiano Da Silva
#
# ...
